# %%
library(phangorn)
# Out:
# Loading required package: ape

# %%
get_likelihoods <- function(log_data, tree_data, test_data, model){

    gamma <- log_data$gammaShape
    freqs <- log_data[c('freqParameter.1','freqParameter.2', 'freqParameter.3', 'freqParameter.4')]
    ex_rates <- log_data[c('rateAC', 'rateAG', 'rateAT', 'rateCG' ,'rateGT')]

    liks <- vector()
    for(i in 1:length(tree_data)){

    if(model == 'JC'){
        liks[i] <- pml(tree = tree_data[[i]], data= test_data)$logLik            
    }else if(model == 'GTR'){
        liks[i] <- pml(tree = tree_data[[i]], data= test_data, bf = as.numeric(freqs[i, ]), Q = as.numeric(c(ex_rates[i, ], 1)), k = 4, shape = gamma[i])$logLik            
    }
    }
    return(liks)
}

# %%
log_data <- read.table('../rhdv/rhdv_train_strict_constant.log', head = T)
log_data <- log_data[(nrow(log_data) - 100):(nrow(log_data)), ]
trees_data <- read.tree('../rhdv/rhdv_train_strict_constant_phylogs.trees')
test_data <- phyDat(read.dna('../rhdv/rhdv_test.fasta', format = 'fasta'))

liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1] -5556.578
# [1] -6279.841
#   [1] -6119.734 -6141.392 -6145.845 -6151.661 -6177.065 -6319.425 -6336.285
#   [8] -6272.813 -6280.531 -6342.392 -6273.462 -6356.518 -6287.895 -6313.035
#  [15] -6291.385 -6342.890 -6307.015 -6242.463 -6295.387 -6261.424 -6243.593
#  [22] -6241.578 -6139.865 -6212.135 -6250.472 -6256.875 -6203.093 -6247.539
#  [29] -6313.315 -6247.940 -6214.116 -6291.834 -6270.630 -6207.924 -6233.686
#  [36] -6239.744 -6190.790 -6240.336 -6240.535 -6154.528 -6162.091 -6405.012
#  [43] -6303.718 -6501.005 -6263.458 -6293.622 -6267.651 -6180.527 -6310.365
#  [50] -6465.890 -6513.183 -6343.802 -6436.485 -6249.603 -6287.803 -6224.799
#  [57] -6378.707 -6322.950 -6374.672 -6207.215 -6214.836 -6252.629 -6213.514
#  [64] -6173.163 -6187.737 -6204.164 -6208.720 -6235.591 -6273.800 -6397.635
#  [71] -6293.936 -6283.664 -6377.761 -6318.628 -6280.970 -6308.009 -6310.047
#  [78] -6291.719 -6256.667 -6481.845 -6308.844 -6314.715 -6374.935 -6216.946
# ...

# %%
log_data <- read.table('../rhdv/rhdv_train2_strict_constant.log', head = T)
log_data <- log_data[(nrow(log_data) - 100):(nrow(log_data)), ]
trees_data <- read.tree('../rhdv/rhdv_train2_strict_constant_phylogs.trees')
test_data <- phyDat(read.dna('../rhdv/rhdv_test2.fasta', format = 'fasta'))

liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1]


liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1] -5412.47
# [1] -6725.927
#   [1] -6831.082 -6784.306 -6778.260 -6753.379 -6655.188 -6892.749 -6637.563
#   [8] -6667.277 -6663.315 -6660.969 -6745.663 -7058.778 -6854.765 -6815.277
#  [15] -6805.227 -6873.725 -6840.856 -6632.218 -6647.313 -6700.329 -6725.037
#  [22] -6734.900 -6706.027 -6601.044 -6893.637 -6702.643 -6796.606 -6639.115
#  [29] -6678.832 -6651.597 -6802.334 -6698.870 -6576.071 -6683.059 -6892.373
#  [36] -6719.337 -6559.427 -6780.450 -6751.382 -6621.652 -6754.971 -6754.620
#  [43] -6571.914 -6534.672 -6580.206 -6815.682 -6660.966 -6913.715 -6661.334
#  [50] -6774.550 -6775.188 -6800.587 -6830.308 -6672.563 -6752.780 -6570.070
#  [57] -6591.535 -6589.803 -6787.278 -6664.071 -6615.948 -6617.749 -6800.295
#  [64] -6620.254 -6691.847 -6861.143 -6697.018 -6717.500 -6635.087 -6577.364
#  [71] -6748.610 -6718.665 -6674.911 -6712.733 -6714.396 -6729.951 -6636.015
#  [78] -6735.345 -6682.063 -6730.378 -6728.148 -6726.448 -6681.761 -6880.923
# ...

# %%
log_data <- read.table('../rhdv/rhdv_train_ucld_constant.log', head = T)
log_data <- log_data[(nrow(log_data) - 100):(nrow(log_data)), ]
trees_data <- read.tree('../rhdv/rhdv_train_ucld_constant_phylogs.trees')
test_data <- phyDat(read.dna('../rhdv/rhdv_test.fasta', format = 'fasta'))


for(i in 1:length(trees_data)){
    trees_data[[i]]$tip.label <- gsub('_|[-]', '', trees_data[[i]]$tip.label)
}

names(test_data) <- gsub('_|[-]', '', names(test_data))

liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1] -5513.815
# [1] -8770.475
#   [1]  -6215.458  -9756.582  -8531.631  -8676.029  -9727.225  -8662.095
#   [7]  -6265.733  -8583.259  -9808.954  -8615.022  -7408.524 -10901.098
#  [13]  -7401.624  -9836.255  -9911.351  -7494.974 -14552.429  -8680.326
#  [19]  -9884.571  -8769.839  -7535.939  -7547.312  -8826.977  -8850.231
#  [25]  -7621.500  -6233.207  -8615.305  -7447.105 -11106.524  -8687.525
#  [31]  -9930.318  -8733.583  -7543.256  -7442.665  -6365.424  -7606.105
#  [37]  -6520.376  -7435.291 -10993.065  -8690.071  -8634.175  -7509.181
#  [43]  -7511.625 -12201.078  -8603.265  -9885.477 -10999.928  -9876.355
#  [49]  -8730.401  -7500.808  -9869.846 -13387.539  -7517.188  -8770.120
#  [55]  -9822.678 -12167.766  -8605.735  -7450.112  -8643.241  -8647.592
#  [61] -12199.294  -6253.677  -8591.505  -6203.243  -8556.320  -8580.757
#  [67]  -8557.350  -9794.573 -11138.893  -8633.189  -6282.271  -7484.912
#  [73]  -8714.382  -9797.273  -7494.359  -6276.383  -9825.330  -8571.595
# ...

# %%
log_data <- read.table('../rhdv/rhdv_train_ucld_exponential.log', head = T)
log_data <- log_data[(nrow(log_data) - 100):(nrow(log_data)), ]
trees_data <- read.tree('../rhdv/rhdv_train_ucld_exponential_phylogs.trees')
test_data <- phyDat(read.dna('../rhdv/rhdv_test.fasta', format = 'fasta'))


for(i in 1:length(trees_data)){
    trees_data[[i]]$tip.label <- gsub('_|[-]', '', trees_data[[i]]$tip.label)
}

names(test_data) <- gsub('_|[-]', '', names(test_data))

liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1] -5507.552
# [1] -8615.482
#   [1]  -7471.422  -8488.932  -7372.799  -8654.204  -8653.343 -12199.051
#   [7]  -8691.782  -9855.816  -8843.922  -9860.464 -12212.685 -10197.332
#  [13]  -8701.960  -8622.339  -9915.004 -11204.462  -7482.894  -8556.229
#  [19]  -7330.969  -8429.362  -7440.760  -7386.906  -7364.703  -8599.926
#  [25] -11071.141  -7358.404 -10907.024  -9646.594  -7564.410 -10943.115
#  [31]  -8556.157  -9752.908  -6180.876  -8775.121  -8758.829  -9854.696
#  [37]  -7533.638  -7476.600  -7543.454  -7545.983  -9837.017  -8653.144
#  [43]  -7379.424  -9704.006 -10913.077  -7329.286  -6190.545  -6169.296
#  [49]  -8589.325  -8596.924  -8581.344  -6158.227 -11050.149  -8642.464
#  [55] -12192.859 -12201.184  -8637.630  -9895.977  -8765.270  -8711.371
#  [61]  -7468.130  -7521.579  -9880.089  -6120.238  -8604.553  -7393.739
#  [67]  -6156.637  -7520.764 -11067.062  -8461.412  -7309.352  -6186.672
#  [73]  -6263.038 -11057.755  -7446.160  -6270.512 -12140.112  -7483.325
# ...

# %%
log_data <- read.table('../rhdv/rhdv_train2_ucld_exponential.log', head = T)
log_data <- log_data[(nrow(log_data) - 100):(nrow(log_data)), ]
trees_data <- read.tree('../rhdv/rhdv_train2_ucld_exponential_phylogs.trees')
test_data <- phyDat(read.dna('../rhdv/rhdv_test2.fasta', format = 'fasta'))


for(i in 1:length(trees_data)){
    trees_data[[i]]$tip.label <- gsub('_|[-]', '', trees_data[[i]]$tip.label)
}

names(test_data) <- gsub('_|[-]', '', names(test_data))

liks <- get_likelihoods(log_data, trees_data, test_data = test_data, model = 'GTR')
print(mean(log_data$likelihood))
print(mean(liks, na.rm = T))
print(liks)
# Out:
# [1] -5379.035
# [1] -9478.565
#   [1] -10429.757 -10164.182 -10216.547 -11414.759  -8322.310 -10132.234
#   [7] -10149.842  -8913.211 -10554.831  -7971.391 -10354.763  -7958.679
#  [13]  -9148.361 -10224.293 -11282.342 -11304.366  -8791.477  -6502.032
#  [19] -10094.983 -11258.495  -7962.903 -10219.963  -7823.550  -7948.193
#  [25] -13976.955  -9384.718  -6742.100  -9101.940 -11498.832 -12712.925
#  [31]  -9176.381  -6811.616  -9255.420 -11606.952  -9115.727  -8249.208
#  [37]  -9311.195  -8091.294  -9190.721 -10486.639  -9228.302  -8072.415
#  [43]  -9281.515  -9122.476 -10312.043 -11720.503  -9497.776 -10351.853
#  [49]  -9219.874  -8281.163  -7905.605  -6780.314  -7910.194  -8861.643
#  [55]  -8007.928 -13754.205  -9239.983 -12603.278 -10195.997 -13846.289
#  [61]  -7882.559 -10345.423  -6817.792  -9142.806 -10363.759  -7985.123
#  [67]  -9154.163  -9046.240 -10582.921 -11570.454 -13933.510  -6925.999
#  [73]  -7810.251 -10184.590  -9020.020 -10212.095  -9122.952  -7950.284
# ...
