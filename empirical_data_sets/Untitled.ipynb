# %%
import sys, os, re
import numpy as np
import pandas as pd
import dendropy as dp
from Bio import SeqIO

# %%
execfile('make_xmls.py')

# %%
secs = parse_fasta('rhdv.fasta')

# %%
make_sequence_block(secs)
# Out:
# '<sequence id="AUS_SA_FlindersRanges_2002.79" taxon="AUS_SA_FlindersRanges_2002.79" totalcount="4" value="..."/>\n<sequence id="KF494932_AUS_SA_PLUM_1995.83" taxon="KF494932_AUS_SA_PLUM_1995.83" totalcount="4" value="..."/>\n<sequence id="KF494911_AUS_ACT_WESTCRK_2011.67" taxon="KF494911_AUS_ACT_WESTCRK_2011.67" totalcount="4" value="..."/>\n<sequence id="KF494944_AUS_SA_TF-PT1743_2008.75" taxon="KF494944_AUS_SA_TF-PT1743_2008.75" totalcount="4" value="..."/>\n<sequence id="KF494943_AUS_SA_TF-PT1731_2008.83" taxon="KF494943_AUS_SA_TF-PT1731_2008.83" totalcount="4" value="..."/>\n<sequence id="KF494919_AUS_NSW_YOUNG_2011.58" taxon="KF494919_AUS_NSW_YOUNG_2011.58" totalcount="4" value="..."/>\n<sequence id="KF494950_AUS_WA_MANMAN_2010.75" taxon="KF494950_AUS_WA_MANMAN_2010.75" totalcount="4" value="..."/>\n<sequence id="KF594475_AUS_SA_Turretfield-07_2007.50" taxon="KF594475_AUS_SA_Turretfield-07_2007.50" totalcount="4" value="..."/>\n<sequence id="AUS_SA_Bulgania_2009.65" taxon="AUS_S
# ...

# %%
get_date('KF494932_AUS_SA_PLUM_1995.83')
# Out:
# '1995.83'

# %%
make_dates_block(secs)
# Out:
# 'AUS_SA_FlindersRanges_2002.79=2002.79,\nKF494932_AUS_SA_PLUM_1995.83=1995.83,\nKF494911_AUS_ACT_WESTCRK_2011.67=2011.67,\nKF494944_AUS_SA_TF-PT1743_2008.75=2008.75,\nKF494943_AUS_SA_TF-PT1731_2008.83=2008.83,\nKF494919_AUS_NSW_YOUNG_2011.58=2011.58,\nKF494950_AUS_WA_MANMAN_2010.75=2010.75,\nKF594475_AUS_SA_Turretfield-07_2007.50=2007.50,\nAUS_SA_Bulgania_2009.65=2009.65,\nKF594476_AUS_SA_Turretfield-09_2009.50=2009.50,\nKF494916_AUS_NSW_ROCKL-1_2011.25=2011.25,\nKF494925_AUS_SA_ECH_2008.75=2008.75,\nKF494915_AUS_NSW_ROCKF-2_2011.33=2011.33,\nKF494934_AUS_SA_ROXDWNS_2011.67=2011.67,\nKF494949_AUS_TAS_STHARM_2007.42=2007.42,\nAUS_SA_Motpena_2013.72=2013.72,\nKF494935_AUS_SA_TF-07_1999.83=1999.83,\nAUS_WA_Bunbury_2000.13=2000.13,\nAUS_SA_BillaKallina_2004.50=2004.50,\nKF494918_AUS_NSW_WOODSTK_2011.25=2011.25,\nAUS_NSW_Murrumbateman_BlueGums_2014.24=2014.24,\nKF494906_AUS_ACT_GUN-01_2009.25=2009.25,\nKF494945_AUS_SA_TF-PT1839_2009.83=2009.83,\nAUS_SA_Woodcroft_2005.76=2005.76,\nKF494910
# ...

# %%
','.join(['2', '3', '45', '45'])
# Out:
# '2,3,45,45'

# %%
open('test_strict_constant.xml', 'w').writelines(make_strict_constant(secs, 'test_strict_constant.xml'))

# %%
open('test_expon.xml', 'w').writelines(make_strict_exponential(secs, 'test_strict_exponential'))
