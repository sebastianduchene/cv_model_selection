# %%
import sys, os, re
import numpy as np
import pandas as pd
import dendropy as dp
from Bio import SeqIO

# %%
rhdv = dp.DnaCharacterMatrix.get_from_path('RHDV.MolEpi.AUS.BEAST.Big-VP60.nex', 'nexus')

# %%
for t in rhdv.taxon_namespace:
    t.label = re.sub('/', '_', t.label)

# %%
rhdv.write_to_path('rhdv.fasta', 'fasta')

# %%
len(rhdv)
# Out:
# 72
