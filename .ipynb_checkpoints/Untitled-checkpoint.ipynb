# %%
import dendropy as dp
import numpy as np
import copy as copy

# %%
trees = dp.TreeList.get_from_path('wowow.trees', 'nexus', extract_comment_metadata = True)

# %%
phylogs = trees[0]

# %%
new_tree = copy.copy(trees[0])
for b in new_tree.postorder_edge_iter():
    blen = float(b.head_node.annotations['rate']) * b.length
    b.length = blen
    
#        print n.length
#        next

# %%
for b in new_tree.postorder_edge_iter():
    print b.length
# Out:
# 0.268351078782
# 0.0842011358079
# 1.02371281082
# 0.120984352408
# 0.930813342828
# 1.50316770366
# 0.104891870225
# 0.101762716343
# 0.49235939343
# 0.261023836986
# 0.547851286991
# 0.162275366646
# 0.387613153729
# 0.610195351467
# 0.00829589255406
# 0.083643286832
# 0.0058959763393
# 0.00957603415601
# 0.110559885798
# 0.072477202135
# 0.10279718543
# 0.518374141455
# 0.411686281679
# 0.116392095716
# 1.38495368362
# 1.33444591569
# 0.0794680263982
# 0.396618216065
# 0.0986860290353
# 0.102234102795
# 0.129198199613
# 0.373435979765
# 2.29590210179
# 0.270946293029
# 0.623510751103
# 0.125374754303
# 4.74030867482
# 0.182603640353
# 0.485496544721
# 0.162957936728
# 0.165834332831
# 2.94053633393
# 1.61767140861
# 0.0161155448635
# 0.141601060197
# 0.168679304117
# 0.189910677775
# 0.168289717508
# 1.98366896906
# 0.936401745661
# 0.286583351964
# 0.0294048079377
# 1.26767627005
# 0.0274701689394
# 0.332111234515
# 0.177772532907
# 4.07101737283
# 0.0960363652279
# ...
