# %%
import p4
import sys
import pandas as pd

print '''
The order of the arguments is:
- test set file
- log file
- phylograms file
'''


print sys.argv
# Out:
# The order of the arguments is:
# - test set file
# - log file
# - phylograms file
#
# ['/Users/sebastianducheneAIr/ipykernel/ipykernel/__main__.py', '-f', '/Users/sebastianducheneAIr/Library/Jupyter/runtime/kernel-019f70f5-12f1-4886-8a71-9f59466acffd.json']

# %%
test_set_file = 's3_strict_test.fasta'
log_file = 's3_strict_subset_strict.log'
phylogs_file = 's3_strict_subset_strict_phylogs.trees'

# %%
p4.read(test_set_file)
a = p4.var.alignments[0]

p4.read(phylogs_file)

# %%
for i in range(len(p4.var.trees)):
    print i
    t = p4.var.trees[i]
    t.data = p4.Data(a)
    t.newComp(free = 1, spec = 'equal')
    t.newRMatrix(free = 0, spec = 'ones')
    t.setNGammaCat(partNum = 0, nGammaCat=1)
#    t.newGdasrv(partNum=0,free = 1, val = gamma.ix[i])
    t.setPInvar(free = 0, val = 0.0)
    t.calcLogLike()
    t.model = None
# Out:
# 0
# Tree.calcLogLike(). -20030.144818
# 1
# Tree.calcLogLike(). -19997.841650
# 2
# Tree.calcLogLike(). -20015.322056
# 3
# Tree.calcLogLike(). -20023.709110
# 4
# Tree.calcLogLike(). -20024.930606
# 5
# Tree.calcLogLike(). -20019.434652
# 6
# Tree.calcLogLike(). -20041.636389
# 7
# Tree.calcLogLike(). -20033.421126
# 8
# Tree.calcLogLike(). -20022.847635
# 9
# Tree.calcLogLike(). -20024.784703
# 10
# Tree.calcLogLike(). -20021.917518
# 11
# Tree.calcLogLike(). -20018.319342
# 12
# Tree.calcLogLike(). -20012.556985
# 13
# Tree.calcLogLike(). -20023.123611
# 14
# Tree.calcLogLike(). -20024.126827
# 15
# Tree.calcLogLike(). -20026.636112
# 16
# Tree.calcLogLike(). -20039.524318
# 17
# Tree.calcLogLike(). -20020.229386
# 18
# Tree.calcLogLike(). -20025.495029
# 19
# Tree.calcLogLike(). -20022.026117
# 20
# Tree.calcLogLike(). -20017.522500
# 21
# Tree.calcLogLike(). -20007.088741
# 22
# Tree.calcLogLike(). -20009.684874
# 23
# Tree.calcLogLike(). -20009.334928
# 24
# Tree.calcLogLike(). -20035.421933
# 25
# Tree.calcLogLike(). -20021.787478
# 26
# Tree.calcLogLike(). -20013.317202
# 27
# Tree.calcLogLike(). -20015.016207
# 28
# Tree.calcLogLike(). -20014.031974
# 29
# Tree.calcLogLike(). -20004.548941
# 30
# Tree.calcLogLike(). -20022.989428
# 31
# Tree.calcLogLike(). -20030.828183
# 32
# Tree.calcLogLike(). -20029.529487
# 33
# Tree.calcLogLike(). -20005.083354
# 34
# Tree.calcLogLike(). -20034.958600
# 35
# Tree.calcLogLike(). -20013.326695
# 36
# Tree.calcLogLike(). -20010.133258
# 37
# Tree.calcLogLike(). -20002.707244
# 38
# Tree.calcLogLike(). -20010.217526
# 39
# Tree.calcLogLike(). -20007.641453
# 40
# Tree.calcLogLike(). -20012.376552
# 41
# Tree.calcLogLike(). -20010.622165
# 42
# Tree.calcLogLike(). -20023.579970
# 43
# Tree.calcLogLike(). -20010.843150
# 44
# Tree.calcLogLike(). -20026.045499
# 45
# Tree.calcLogLike(). -20018.748154
# 46
# Tree.calcLogLike(). -20019.200776
# 47
# Tree.calcLogLike(). -20022.917082
# 48
# Tree.calcLogLike(). -20015.368597
# 49
# Tree.calcLogLike(). -20008.077624
# 50
# Tree.calcLogLike(). -20012.783932
# 51
# Tree.calcLogLike(). -20015.245283
# 52
# Tree.calcLogLike(). -20001.353717
# 53
# Tree.calcLogLike(). -20030.304015
# 54
# Tree.calcLogLike(). -20028.099964
# 55
# Tree.calcLogLike(). -20048.855849
# 56
# Tree.calcLogLike(). -20002.753937
# 57
# Tree.calcLogLike(). -20020.620730
# 58
# Tree.calcLogLike(). -20003.843787
# 59
# Tree.calcLogLike(). -20016.166009
# 60
# Tree.calcLogLike(). -20030.154825
# 61
# Tree.calcLogLike(). -20036.507927
# 62
# Tree.calcLogLike(). -20006.952497
# 63
# Tree.calcLogLike(). -20023.361854
# 64
# Tree.calcLogLike(). -20025.103445
# 65
# Tree.calcLogLike(). -20033.635138
# 66
# Tree.calcLogLike(). -20031.948698
# 67
# Tree.calcLogLike(). -20017.408606
# 68
# Tree.calcLogLike(). -20017.059557
# 69
# Tree.calcLogLike(). -20038.054350
# 70
# Tree.calcLogLike(). -20014.742152
# 71
# Tree.calcLogLike(). -20018.176398
# 72
# Tree.calcLogLike(). -20009.096429
# 73
# Tree.calcLogLike(). -20017.737766
# 74
# Tree.calcLogLike(). -20018.249329
# 75
# Tree.calcLogLike(). -20001.696120
# 76
# Tree.calcLogLike(). -20031.967002
# 77
# Tree.calcLogLike(). -20027.212623
# 78
# Tree.calcLogLike(). -20038.444192
# 79
# Tree.calcLogLike(). -20025.301297
# 80
# Tree.calcLogLike(). -20017.758352
# 81
# Tree.calcLogLike(). -20019.754974
# 82
# Tree.calcLogLike(). -20005.601841
# 83
# Tree.calcLogLike(). -20018.724341
# 84
# Tree.calcLogLike(). -20030.868445
# 85
# Tree.calcLogLike(). -20038.682740
# 86
# Tree.calcLogLike(). -20012.980037
# 87
# Tree.calcLogLike(). -20023.341092
# 88
# Tree.calcLogLike(). -20012.909605
# 89
# Tree.calcLogLike(). -20021.631032
# 90
# Tree.calcLogLike(). -20032.533748
# 91
# Tree.calcLogLike(). -20027.438363
# 92
# Tree.calcLogLike(). -20023.798259
# 93
# Tree.calcLogLike(). -20008.754065
# 94
# Tree.calcLogLike(). -20032.752342
# 95
# Tree.calcLogLike(). -20015.201266
# 96
# Tree.calcLogLike(). -20008.872951
# 97
# Tree.calcLogLike(). -20024.870157
# 98
# Tree.calcLogLike(). -20022.194361
# 99
# Tree.calcLogLike(). -20012.079644
# 100
# Tree.calcLogLike(). -20011.816846
